# %%
import feedparser as fp
import json
import newspaper
from newspaper import Article
from time import mktime
from datetime import datetime
import pandas as pd

# %%
# Set the limit for number of articles to download
LIMIT = 4
data = {}
data['newspapers'] = {}

# %%
# Loads the JSON files with news sites
with open('NewsPapers.json') as data_file:
    companies = json.load(data_file)

count = 1

# %%
# Iterate through each news company
for company, value in companies.items():
    # If a RSS link is provided in the JSON file, this will be the first choice.
    # Reason for this is that, RSS feeds often give more consistent and correct data.
    # If you do not want to scrape from the RSS-feed, just leave the RSS attr empty in the JSON file.
    if 'rss' in value:
        d = fp.parse(value['rss'])
        print("Downloading articles from ", company)
        newsPaper = {
            "rss": value['rss'],
            "link": value['link'],
            "articles": []
        }
        for entry in d.entries:
            # Check if publish date is provided, if no the article is skipped.
            # This is done to keep consistency in the data and to keep the script from crashing.
            if hasattr(entry, 'published'):
                if count > LIMIT:
                    break
                article = {}
                article['link'] = entry.link
                date = entry.published_parsed
                article['published'] = datetime.fromtimestamp(mktime(date)).isoformat()
                try:
                    content = Article(entry.link)
                    content.download()
                    content.parse()
                except Exception as e:
                    # If the download for some reason fails (ex. 404) the script will continue downloading
                    # the next article.
                    print(e)
                    print("continuing...")
                    continue
                article['title'] = content.title
                article['text'] = content.text
                newsPaper['articles'].append(article)
                print(count, "articles downloaded from", company, ", url: ", entry.link)
                count = count + 1
    else:
        # This is the fallback method if a RSS-feed link is not provided.
        # It uses the python newspaper library to extract articles
        print("Building site for ", company)
        paper = newspaper.build(value['link'], memoize_articles=False)
        newsPaper = {
            "link": value['link'],
            "articles": []
        }
        noneTypeCount = 0
        for content in paper.articles:
            if count > LIMIT:
                break
            try:
                content.download()
                content.parse()
            except Exception as e:
                print(e)
                print("continuing...")
                continue
            # Again, for consistency, if there is no found publish date the article will be skipped.
            # After 10 downloaded articles from the same newspaper without publish date, the company will be skipped.
            if content.publish_date is None:
                print(count, " Article has date of type None...")
                noneTypeCount = noneTypeCount + 1
                if noneTypeCount > 10:
                    print("Too many noneType dates, aborting...")
                    noneTypeCount = 0
                    break
                count = count + 1
                continue
            article = {}
            article['title'] = content.title
            article['text'] = content.text
            article['link'] = content.url
            article['published'] = content.publish_date.isoformat()
            newsPaper['articles'].append(article)
            print(count, "articles downloaded from", company, " using newspaper, url: ", content.url)
            count = count + 1
            noneTypeCount = 0
    count = 1
    data['newspapers'][company] = newsPaper

# Finally it saves the articles as a JSON-file.
try:
    with open('scraped_articles.json', 'w') as outfile:
        json.dump(data, outfile)

except Exception as e: print(e)
# Out:
# Building site for  cnn
# 1  Article has date of type None...
# 2  Article has date of type None...
# Downloading articles from  bbc
# 1 articles downloaded from bbc , url:  https://www.bbc.co.uk/news/uk-53091856
# 2 articles downloaded from bbc , url:  https://www.bbc.co.uk/news/uk-53093127
# 3 articles downloaded from bbc , url:  https://www.bbc.co.uk/news/uk-scotland-53083995
# 4 articles downloaded from bbc , url:  https://www.bbc.co.uk/news/uk-politics-53093244
# Downloading articles from  theguardian
# 1 articles downloaded from theguardian , url:  https://www.theguardian.com/politics/2020/jun/18/dominic-raab-taking-the-knee-feels-like-symbol-of-subjugation
# 2 articles downloaded from theguardian , url:  https://www.theguardian.com/education/2020/jun/18/campaign-doesnt-end-with-rhodes-statue-says-oxford-group
# 3 articles downloaded from theguardian , url:  https://www.theguardian.com/uk-news/2020/jun/18/blm-protests-prompt-edinburgh-to-reassess-fate-of-golliwog-mural
# 4 articles downloaded from theguardian , url:  https://www.theguardian.com/environment/2020/jun/18/environmental-justice-means-racial-justice-say-activists
# Building site for  breitbart
# 1 articles downloaded from breitbart  using newspaper, url:  http://www.breitbart.com/politics/2020/06/18/supreme-court-rejects-trump-admins-rescinding-of-daca/
# 2 articles downloaded from breitbart  using newspaper, url:  http://www.breitbart.com/economy/2020/06/18/weekly-jobless-claims-sink-slightly-to-1-51-million-higher-than-expected/
# 3 articles downloaded from breitbart  using newspaper, url:  http://www.breitbart.com/politics/2020/06/18/fulton-county-da-we-need-to-bypass-grand-juries-indict-police-officers-directly/
# 4 articles downloaded from breitbart  using newspaper, url:  http://www.breitbart.com/clips/2020/06/18/burke-county-ga-sheriff-on-atlanta-police-shooting-nothing-malicious-or-sadistic-in-the-way-these-officers-behaved/
# Building site for  infowars
# 1  Article has date of type None...
# 2 articles downloaded from infowars  using newspaper, url:  https://www.infowars.com/im-scared-seattle-residents-living-near-chop-frightened-for-their-safety/
# 3 articles downloaded from infowars  using newspaper, url:  https://www.infowars.com/im-scared-seattle-residents-living-near-chop-frightened-for-their-safety/#vuukle-comments
# 4 articles downloaded from infowars  using newspaper, url:  https://www.infowars.com/publishing-staff-threaten-to-quit-unless-jk-rowlings-new-book-is-canceled/
# Building site for  foxnews
# 1  Article has date of type None...
# 2  Article has date of type None...
# 3  Article has date of type None...
# 4  Article has date of type None...
# Building site for  nbcnews
# 1 articles downloaded from nbcnews  using newspaper, url:  https://www.nbcnews.com/politics/supreme-court/supreme-court-rules-trump-cannot-end-daca-big-win-dreamer-n1115116
# 2  Article has date of type None...
# 3  Article has date of type None...
# 4  Article has date of type None...
# Downloading articles from  washingtonpost
# 1 articles downloaded from washingtonpost , url:  https://www.washingtonpost.com/world/2020/06/18/beijing-coronavirus-outbreak-meaning/?utm_source=rss&utm_medium=referral&utm_campaign=wp_world
# 2 articles downloaded from washingtonpost , url:  https://www.washingtonpost.com/world/europe/macron-visits-london-in-first-foreign-visit-since-coronavirus-lockdown-but-the-trip-is-hardly-business-as-usual/2020/06/18/e5f745c8-b0d6-11ea-98b5-279a6479a1e4_story.html?utm_source=rss&utm_medium=referral&utm_campaign=wp_world
# 3 articles downloaded from washingtonpost , url:  https://www.washingtonpost.com/world.asia_pacific/trump-signs-uighur-sanctions-bill-amid-bolton-criticism-drawing-fury-from-china/2020/06/18/df27ba4c-b10e-11ea-98b5-279a6479a1e4_story.html?utm_source=rss&utm_medium=referral&utm_campaign=wp_world
# 4 articles downloaded from washingtonpost , url:  https://www.washingtonpost.com/world/2020/01/22/mapping-spread-new-coronavirus/?utm_source=rss&utm_medium=referral&utm_campaign=wp_world

# %%
# Finally it saves the articles as a JSON-file.
try:
    with open('scraped_articles.csv', 'w') as outfile:
        json.dump(data, outfile)
except Exception as e: print(e)

# %%
'''ab humare pass do dataset hai 
ek to wahi purana waala 
aur dusra 
jo abhi upar hai
ab hum log nltk aur dl aur ml ek aadh algo lagayenge
we may also use yoda parser in order to shift noun ahead

'''

# %%
import pandas as pd
df_one=pd.read_pickle("/home/rd/Desktop/prj/cleaned_df.pkl")

# %%
df_one
# Out:
#                                                   link            published  \
# 0    https://www.nytimes.com/2019/11/20/business/me...  2019-11-21T04:22:14
# 1    https://www.nytimes.com/2019/11/20/business/gm...  2019-11-21T00:07:24
# 2    https://www.nytimes.com/2019/11/20/business/ho...  2019-11-21T01:58:42
# 3    https://www.nytimes.com/2019/11/20/business/tr...  2019-11-21T02:08:37
# 4    https://www.nytimes.com/2019/11/21/business/de...  2019-11-21T08:00:10
# ..                                                 ...                  ...
# 465  https://nbpostgazette.com/great-lakes-student-...  2019-11-20T05:40:09
# 466  https://nbpostgazette.com/5-ways-to-use-credit...  2019-11-19T23:26:56
# 467  https://nbpostgazette.com/8-reasons-to-love-ne...  2019-11-19T22:25:53
# 468  https://nbpostgazette.com/indigo-card-login-re...  2019-11-19T09:53:42
# 469  https://nbpostgazette.com/mybpcreditcard-login...  2019-11-19T09:37:46
#
#                                                  title  \
# 0    Media Workers Call Out Pay Gaps in Crowdsource...
# 1    G.M. Sues Rival Over Bribery Scheme as Union S...
# 2    U.S. Bill Supporting Hong Kong Rights Heads to...
# 3    Trump Floats Tariff Exclusions for Apple at Te...
# 4    Henry Paulson Sounds Alarm: U.S.-China Relatio...
# ..                                                 ...
# 465  Great Lakes Student Loans: Everything You Need...
# 466  Top 5 Ways To Use Your Credit Card Efficiently...
# 467  Here Are Top 8 Reasons To Love New Brunswick, ...
# 468  Indigo Card Login, Register Activate At Myindi...
# 469  MyBPCreditcard Login Guide At www.mybpcreditca...
#
#                                                   text  \
# 0    With income inequality a focus of the current ...
# 1    Fiat Chrysler “was able to obtain unique advan...
# 2    A bill compelling the United States to support...
# 3    Jonathan Gold, a spokesman for Americans for F...
# 4    The United States and China will eventually se...
# ..                                                 ...
# 465  If you are looking for a student loan, then yo...
# 466  The world is growing digital and so are curren...
# 467  If you love traveling then you would have sure...
# 468  Indigo Card Login: The Indigo credit cards can...
# 469  MyBPCreditcard Login: BP Credit Card is being ...
#
#                                     author  label  \
# 0                [Marc Tracy, Tiffany Hsu]      0
# 1                       [Neal E. Boudette]      0
# 2    [David Yaffe-Bellany, Alan Rappeport]      0
# 3                            [Ana Swanson]      0
# 4                     [Andrew Ross Sorkin]      0
# ..                                     ...    ...
# 465       [Trey Warsame, About The Author]      1
# 466       [Trey Warsame, About The Author]      1
# 467       [Trey Warsame, About The Author]      1
# 468     [Carrie Brunner, About The Author]      1
# 469     [Carrie Brunner, About The Author]      1
#
#                                            clean_title  \
# 0    media workers call pay gaps crowdsourced sprea...
# 1    gm sues rival bribery scheme union scandal exp...
# 2    us bill supporting hong kong rights heads trum...
# 3    trump floats tariff exclusions apple texas man...
# 4    henry paulson sounds alarm us china relations ...
# ..                                                 ...
# 465     great lakes student loans everything need know
# 466        top ways use credit card efficiently wisely
# 467              top reasons love new brunswick canada
# 468  indigo card login register activate myindigoca...
# 469  mybpcreditcard login guide wwwmybpcreditcardco...
#
#                                             clean_text
# 0    income inequality focus current presidential c...
# 1    fiat chrysler "was able obtain unique advantag...
# 2    bill compelling united states support pro demo...
# 3    jonathan gold spokesman americans free trade l...
# 4    united states china eventually settle differen...
# ..                                                 ...
# 465  looking student loan might definitely heard na...
# 466  world growing digital currencies digital payme...
# 467  love traveling would surely heard new brunswic...
# 468  indigo card login indigo credit cards help ord...
# 469  mybpcreditcard login bp credit card issued syn...
#
# [470 rows x 8 columns]

# %%
df_two=pd.read_json("/home/rd/Desktop/prj/scraped_articles.json")

# %%
df_two
# Out:
#                                                        newspapers
# bbc             {'rss': 'http://feeds.bbci.co.uk/news/rss.xml'...
# breitbart       {'link': 'http://www.breitbart.com/', 'article...
# cnn             {'link': 'http://edition.cnn.com/', 'articles'...
# foxnews         {'link': 'http://www.foxnews.com/', 'articles'...
# infowars        {'link': 'https://www.infowars.com/', 'article...
# nbcnews         {'link': 'http://www.nbcnews.com/', 'articles'...
# theguardian     {'rss': 'https://www.theguardian.com/uk/rss', ...
# washingtonpost  {'rss': 'http://feeds.washingtonpost.com/rss/w...

# %%
df_
